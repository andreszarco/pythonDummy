# %% [markdown]
# # Introducción a la ciencia de datos con Python
# ###  Rafa Caballero
#
# ### Proyecto 3
#
# Ejecutar las siguientes celdas para instalar yfinance y valores de Google en los últimos meses (si da error porque no está instalada ejecutar la casilla siguiente quitando el comentario para la instalación)

# %%
#!pip install yfinance

# %%
import pandas as pd
import yfinance as yf

valor = "GOOGL"
df_google = yf.download(valor,
                      start='2022-01-01',
                      end='2024-06-30')
df_google['Close'].plot(title=valor)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# <Axes: title={'center': 'GOOGL'}, xlabel='Date'>

# %% [markdown]
# ### Ejercicio 1
# Obtener información básica para ver las columnas, sus tipos y si hay nulos

# %%
# Solución
# list all columns
#df_google.columns

#types of columns
#df_google.dtypes

# Do you have null data in the data frame?
#df_google.isnull().sum()

#Set cell to None (Null) for test.
#df_google.Close[0] = None


df_result = pd.DataFrame({'type': df_google.dtypes, 'hasNull': df_google.isnull().sum() })
df_result
# Out:
#               type  hasNull
# Open       float64        0
# High       float64        0
# Low        float64        0
# Close       object        1
# Adj Close  float64        0
# Volume       int64        0

# %% [markdown]
# ### Ejercicio 2
# Hacer histogramas de todas las columnas y boxplots solo de la columna Volume ¿Tiene valores significativamente altos o bajos?

# %%
# Histogramas
import matplotlib.pyplot as plt
plt.hist(df_google.Volume)
# Out:
# (array([ 67., 316., 154.,  51.,  21.,   9.,   3.,   2.,   0.,   2.]),
#  array([9.7014000e+06, 2.1051260e+07, 3.2401120e+07, 4.3750980e+07,
#         5.5100840e+07, 6.6450700e+07, 7.7800560e+07, 8.9150420e+07,
#         1.0050028e+08, 1.1185014e+08, 1.2320000e+08]),
#  <BarContainer object of 10 artists>)

# %%
#Boxplots

# %% [markdown]
# ### Ejercicio 3
# Crear un dataframe df_percent con los incrementos en tanto por 100 con respecto al día anterior

# %%
# Solución

# %% [markdown]
# ### Ejercicio 4
# Crear un dataframe df2 solo las 10 primeras filas de df_google

# %%
# Solución

# %% [markdown]
# ### Ejercicio 5
# Mostrar la media de Open y de Close en df_google

# %%
# Solución

# %% [markdown]
# ### Ejercicio 6
# Añadir a df_google una columna "dif" que contenga la diferencia entre el valor Open y Close

# %%
# Solución

# %% [markdown]
# ### Ejercicio 7
# Calcular que proporción de filas tienen Open-Close >0 (se puede usar la columna dif si se desea)

# %%
# Solución

# %% [markdown]
# ### Ejercicio 8
# Calcular la proporción de filas es las que el volumen  (Volume) es superior a la media (de la propia columna Volume)

# %%
# Solución

# %% [markdown]
# ### Ejercicio 9
# Crear una nueva columna "inc" que tome el valor "positivo" si Open-Close>0, "negativo" si Open-Close<0 e "igual" en otro caso

# %%
# Solución

# %% [markdown]
# ### Ejercicio 10
# Grabar dos libros excel, uno "positivo.xlsx" solo con las filas que tengan "inc" a "positivo" y otra "negativo.xlsx" solo con las que tengan "inc" a "negativo"

# %%
# solución
